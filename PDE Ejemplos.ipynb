# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import pdesolver

# %%
eq= {}
eq['D'] = 1/np.pi
eq['ic'] = lambda x : np.sin(np.pi*x)
eq['bcL'] = lambda t : 0
eq['bcR'] = lambda t : -np.pi*np.exp(-np.pi*t)
M = 20
N = 256
Ix = [0, 1]
It = [0, 1]

W, X, T = pdesolver.explicitHeat(eq, Ix, It, M, N)

# %%
u = lambda x, t: np.exp(-np.pi*t)*np.sin(np.pi*x)
U = np.array([[u(x,t) for t in T] for x in X])
E = abs(U-W)
print(E)
# Out:
# [[0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 7.78727645e-06 1.53842047e-05 ... 2.57660317e-05
#   2.61654234e-05 2.65601105e-05]
#  [0.00000000e+00 1.53828043e-05 3.03895992e-05 ... 5.30285110e-05
#   5.38093779e-05 5.45733400e-05]
#  ...
#  [0.00000000e+00 1.53828043e-05 3.03895992e-05 ... 1.16364929e-03
#   1.15873531e-03 1.15384878e-03]
#  [0.00000000e+00 7.78727645e-06 4.01500726e-04 ... 1.23656228e-03
#   1.23084946e-03 1.22517632e-03]
#  [0.00000000e+00 8.38196886e-04 1.37862902e-03 ... 1.29868238e-03
#   1.29224205e-03 1.28585109e-03]]

# %%
MeshT, MeshX = np.meshgrid(T, X)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_wireframe(MeshT, MeshX, U)

ax.text2D(0, 1, "Solucion Exacta", transform=ax.transAxes)
ax.set_xlabel('Tiempo (t)')
ax.set_ylabel('Espacio (x)')
ax.set_zlabel('u(t,x)')

plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_wireframe(MeshT, MeshX, W, cmap=cm.jet)

ax.text2D(0, 1, "Solucion Metodo Explicito", transform=ax.transAxes)
ax.set_xlabel('Tiempo (t)')
ax.set_ylabel('Espacio (x)')
ax.set_zlabel('u(t,x)')

plt.show()

# %%
M = 20
N = 10
Ix = [0, 1]
It = [0, 1]

W, X, T = pdesolver.implicitHeat(eq, Ix, It, M, N)

# %%
U = np.array([[u(x,t) for t in T] for x in X])
E = abs(U-W)
print(E)
# Out:
# [[0.00000000e+00 1.24132053e-15 9.47314276e-16 7.26181181e-16
#   5.60149822e-16 4.35531087e-16 3.41894893e-16 2.71365826e-16
#   2.18037805e-16 1.77503851e-16 1.46487597e-16]
#  [0.00000000e+00 4.88124100e-03 7.39997696e-03 8.51129210e-03
#   8.81584791e-03 8.67764347e-03 8.31078217e-03 7.83798269e-03
#   7.32773911e-03 6.81702226e-03 6.32479884e-03]
#  [0.00000000e+00 9.64695536e-03 1.46333782e-02 1.68437103e-02
#   1.74612143e-02 1.72024411e-02 1.64890403e-02 1.55630812e-02
#   1.45600753e-02 1.35535208e-02 1.25814215e-02]
#  [0.00000000e+00 1.41848275e-02 2.15385914e-02 2.48239685e-02
#   2.57710634e-02 2.54264286e-02 2.44064003e-02 2.30658189e-02
#   2.16043410e-02 2.01311358e-02 1.87033882e-02]
#  [0.00000000e+00 1.83889138e-02 2.79638473e-02 3.22898438e-02
#   3.35911226e-02 3.32112739e-02 3.19426669e-02 3.02434307e-02
#   2.83732531e-02 2.64757651e-02 2.46275581e-02]
#  [0.00000000e+00 2.21627062e-02 3.37719361e-02 3.90954289e-02
#   4.07829424e-02 4.04327694e-02 3.89896155e-02 3.70029602e-02
#   3.47873911e-02 3.25195221e-02 3.02956629e-02]
#  [0.00000000e+00 2.54220593e-02 3.88446848e-02 4.51160542e-02
#   4.72285767e-02 4.69849411e-02 4.54544310e-02 4.32640540e-02
#   4.07774259e-02 3.82024926e-02 3.56556847e-02]
#  [0.00000000e+00 2.80979515e-02 4.30871286e-02 5.02527765e-02
